# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("1. Regression - Module - (Housing Prices).csv")

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# 1              No                 NaN  ...             7
# 2              No                 NaN  ...             6
# 3              No                 NaN  ...             7
# 4              No                 NaN  ...             8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# 1                                     2170.0                      400
# 2                                      770.0                        0
# 3                                     1050.0                      910
# 4                                     1680.0                        0
#
#    Age of House (in Years)  Renovated Year  Zipcode  Latitude  Longitude  \
# 0                       63               0  98178.0   47.5112   -122.257
# 1                       67            1991  98125.0   47.7210   -122.319
# 2                       85               0  98028.0   47.7379   -122.233
# 3                       53               0  98136.0   47.5208   -122.393
# 4                       31               0  98074.0   47.6168   -122.045
#
#    Living Area after Renovation (in Sqft)  Lot Area after Renovation (in Sqft)
# 0                                  1340.0                                 5650
# 1                                  1690.0                                 7639
# 2                                  2720.0                                 8062
# 3                                  1360.0                                 5000
# 4                                  1800.0                                 7503
#
# [5 rows x 21 columns]

# %%
data.isnull().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# Longitude                                        1
# Living Area after Renovation (in Sqft)           1
# Lot Area after Renovation (in Sqft)              0
# dtype: int64

# %%
data.dropna(subset=["Sale Price","Zipcode"],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21608 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21608 non-null  int64
#  1   Date House was Sold                        21608 non-null  object
#  2   Sale Price                                 21608 non-null  float64
#  3   No of Bedrooms                             21608 non-null  int64
#  4   No of Bathrooms                            21604 non-null  float64
#  5   Flat Area (in Sqft)                        21599 non-null  float64
#  6   Lot Area (in Sqft)                         21599 non-null  float64
#  7   No of Floors                               21608 non-null  float64
#  8   Waterfront View                            21608 non-null  object
#  9   No of Times Visited                        2124 non-null   object
#  10  Condition of the House                     21608 non-null  object
#  11  Overall Grade                              21608 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21605 non-null  float64
#  13  Basement Area (in Sqft)                    21608 non-null  int64
#  14  Age of House (in Years)                    21608 non-null  int64
#  15  Renovated Year                             21608 non-null  int64
#  16  Zipcode                                    21608 non-null  float64
#  17  Latitude                                   21607 non-null  float64
#  18  Longitude                                  21607 non-null  float64
#  19  Living Area after Renovation (in Sqft)     21607 non-null  float64
#  20  Lot Area after Renovation (in Sqft)        21608 non-null  int64
# dtypes: float64(10), int64(7), object(4)
# memory usage: 3.6+ MB

# %%
from sklearn.impute import SimpleImputer

# %%
data.select_dtypes("float64").columns
# Out:
# Index(['Sale Price', 'No of Bathrooms', 'Flat Area (in Sqft)',
#        'Lot Area (in Sqft)', 'No of Floors',
#        'Area of the House from Basement (in Sqft)', 'Zipcode', 'Latitude',
#        'Longitude', 'Living Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
numerical_features=[ 'Flat Area (in Sqft)',
       'Lot Area (in Sqft)', 
       'Area of the House from Basement (in Sqft)', 'Latitude',
       'Longitude', 'Living Area after Renovation (in Sqft)']

# %%
imputer=SimpleImputer(strategy="mean")

arr=imputer.fit_transform(data[numerical_features])

# %%
data[numerical_features]=arr

# %%
data["No of Bathrooms"].fillna(method="bfill",inplace=True)
# Out:
# C:\Users\PAWAN\AppData\Local\Temp\ipykernel_25980\4181855451.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["No of Bathrooms"].fillna(method="bfill",inplace=True)
# C:\Users\PAWAN\AppData\Local\Temp\ipykernel_25980\4181855451.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data["No of Bathrooms"].fillna(method="bfill",inplace=True)

# %%
data.drop(columns=["No of Times Visited"],inplace=True)

# %%
data.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
def year(value):
    return value.split()[-1]

data["Date House was Sold"]=data["Date House was Sold"].map(year)

# %%
data.head(3)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520                2017    221900.0               3
# 1  6414100192                2017    538000.0               3
# 2  5631500400                2016    180000.0               2
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
#
#   Waterfront View Condition of the House  Overall Grade  \
# 0              No                   Fair              7
# 1              No                   Fair              7
# 2              No                   Fair              6
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# 1                                     2170.0                      400
# 2                                      770.0                        0
#
#    Age of House (in Years)  Renovated Year  Zipcode  Latitude  Longitude  \
# 0                       63               0  98178.0   47.5112   -122.257
# 1                       67            1991  98125.0   47.7210   -122.319
# 2                       85               0  98028.0   47.7379   -122.233
#
#    Living Area after Renovation (in Sqft)  Lot Area after Renovation (in Sqft)
# 0                                  1340.0                                 5650
# 1                                  1690.0                                 7639
# 2                                  2720.0                                 8062

# %%
data["Date House was Sold"]=data["Date House was Sold"].astype("int64")

# %%
data["Year since renovated"]=np.where(data["Renovated Year"]==0,0,abs(data["Date House was Sold"]-data["Renovated Year"]))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21608 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21608 non-null  int64
#  1   Date House was Sold                        21608 non-null  int64
#  2   Sale Price                                 21608 non-null  float64
#  3   No of Bedrooms                             21608 non-null  int64
#  4   No of Bathrooms                            21608 non-null  float64
#  5   Flat Area (in Sqft)                        21608 non-null  float64
#  6   Lot Area (in Sqft)                         21608 non-null  float64
#  7   No of Floors                               21608 non-null  float64
#  8   Waterfront View                            21608 non-null  object
#  9   Condition of the House                     21608 non-null  object
#  10  Overall Grade                              21608 non-null  int64
#  11  Area of the House from Basement (in Sqft)  21608 non-null  float64
#  12  Basement Area (in Sqft)                    21608 non-null  int64
#  13  Age of House (in Years)                    21608 non-null  int64
#  14  Renovated Year                             21608 non-null  int64
#  15  Zipcode                                    21608 non-null  float64
#  16  Latitude                                   21608 non-null  float64
#  17  Longitude                                  21608 non-null  float64
#  18  Living Area after Renovation (in Sqft)     21608 non-null  float64
#  19  Lot Area after Renovation (in Sqft)        21608 non-null  int64
#  20  Year since renovated                       21608 non-null  int64
# dtypes: float64(10), int64(9), object(2)
# memory usage: 3.6+ MB

# %%
zipcode = pd.DataFrame(data.groupby("Zipcode")["Sale Price"].mean().sort_values())

# %%
zipcode
# Out:
#            Sale Price
# Zipcode
# 98002.0  2.342840e+05
# 98168.0  2.403284e+05
# 98032.0  2.512962e+05
# 98001.0  2.808047e+05
# 98148.0  2.849086e+05
# ...               ...
# 98102.0  9.015162e+05
# 98112.0  1.096239e+06
# 98040.0  1.194874e+06
# 98004.0  1.356524e+06
# 98039.0  2.161300e+06
#
# [70 rows x 1 columns]

# %%
zipcode["Zipcode"]=pd.cut(zipcode["Sale Price"],bins=10,labels=["zipcode_group_0",
                                                                "zipcode_group_1",
                                                                "zipcode_group_2",
                                                                "zipcode_group_3",
                                                                "zipcode_group_4",
                                                                "zipcode_group_5",
                                                                "zipcode_group_6",
                                                                "zipcode_group_7",
                                                                "zipcode_group_8",
                                                                "zipcode_group_9"],
                          include_lowest=True)

# %%
zipcode
# Out:
#            Sale Price          Zipcode
# Zipcode
# 98002.0  2.342840e+05  zipcode_group_0
# 98168.0  2.403284e+05  zipcode_group_0
# 98032.0  2.512962e+05  zipcode_group_0
# 98001.0  2.808047e+05  zipcode_group_0
# 98148.0  2.849086e+05  zipcode_group_0
# ...               ...              ...
# 98102.0  9.015162e+05  zipcode_group_3
# 98112.0  1.096239e+06  zipcode_group_4
# 98040.0  1.194874e+06  zipcode_group_4
# 98004.0  1.356524e+06  zipcode_group_5
# 98039.0  2.161300e+06  zipcode_group_9
#
# [70 rows x 2 columns]

# %%
data=pd.merge(left=data,
         right=zipcode,
         left_on="Zipcode",
        how="left",
        right_index=True
         )

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21608 entries, 0 to 21612
# Data columns (total 24 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Zipcode                                    21608 non-null  float64
#  1   ID                                         21608 non-null  int64
#  2   Date House was Sold                        21608 non-null  int64
#  3   Sale Price_x                               21608 non-null  float64
#  4   No of Bedrooms                             21608 non-null  int64
#  5   No of Bathrooms                            21608 non-null  float64
#  6   Flat Area (in Sqft)                        21608 non-null  float64
#  7   Lot Area (in Sqft)                         21608 non-null  float64
#  8   No of Floors                               21608 non-null  float64
#  9   Waterfront View                            21608 non-null  object
#  10  Condition of the House                     21608 non-null  object
#  11  Overall Grade                              21608 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21608 non-null  float64
#  13  Basement Area (in Sqft)                    21608 non-null  int64
#  14  Age of House (in Years)                    21608 non-null  int64
#  15  Renovated Year                             21608 non-null  int64
#  16  Zipcode_x                                  21608 non-null  float64
#  17  Latitude                                   21608 non-null  float64
#  18  Longitude                                  21608 non-null  float64
#  19  Living Area after Renovation (in Sqft)     21608 non-null  float64
#  20  Lot Area after Renovation (in Sqft)        21608 non-null  int64
#  21  Year since renovated                       21608 non-null  int64
#  22  Sale Price_y                               21608 non-null  float64
#  23  Zipcode_y                                  21608 non-null  category
# dtypes: category(1), float64(12), int64(9), object(2)
# memory usage: 4.0+ MB

# %%
data.head(3)
# Out:
#    Zipcode          ID  Date House was Sold  Sale Price_x  No of Bedrooms  \
# 0  98178.0  7129300520                 2017      221900.0               3
# 1  98125.0  6414100192                 2017      538000.0               3
# 2  98028.0  5631500400                 2016      180000.0               2
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
#
#   Waterfront View  ... Age of House (in Years)  Renovated Year  Zipcode_x  \
# 0              No  ...                      63               0    98178.0
# 1              No  ...                      67            1991    98125.0
# 2              No  ...                      85               0    98028.0
#
#    Latitude  Longitude  Living Area after Renovation (in Sqft)  \
# 0   47.5112   -122.257                                  1340.0
# 1   47.7210   -122.319                                  1690.0
# 2   47.7379   -122.233                                  2720.0
#
#    Lot Area after Renovation (in Sqft)  Year since renovated   Sale Price_y  \
# 0                                 5650                     0  310612.755725
# 1                                 7639                    26  469485.039024
# 2                                 8062                     0  462488.869258
#
#          Zipcode_y
# 0  zipcode_group_0
# 1  zipcode_group_1
# 2  zipcode_group_1
#
# [3 rows x 24 columns]

# %%
data.rename(columns={"Sale Price_x":"Sale Price"},inplace=True)

# %%
data.drop(columns=["Sale Price_y","Zipcode_x"],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21608 entries, 0 to 21612
# Data columns (total 22 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Zipcode                                    21608 non-null  float64
#  1   ID                                         21608 non-null  int64
#  2   Date House was Sold                        21608 non-null  int64
#  3   Sale Price                                 21608 non-null  float64
#  4   No of Bedrooms                             21608 non-null  int64
#  5   No of Bathrooms                            21608 non-null  float64
#  6   Flat Area (in Sqft)                        21608 non-null  float64
#  7   Lot Area (in Sqft)                         21608 non-null  float64
#  8   No of Floors                               21608 non-null  float64
#  9   Waterfront View                            21608 non-null  object
#  10  Condition of the House                     21608 non-null  object
#  11  Overall Grade                              21608 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21608 non-null  float64
#  13  Basement Area (in Sqft)                    21608 non-null  int64
#  14  Age of House (in Years)                    21608 non-null  int64
#  15  Renovated Year                             21608 non-null  int64
#  16  Latitude                                   21608 non-null  float64
#  17  Longitude                                  21608 non-null  float64
#  18  Living Area after Renovation (in Sqft)     21608 non-null  float64
#  19  Lot Area after Renovation (in Sqft)        21608 non-null  int64
#  20  Year since renovated                       21608 non-null  int64
#  21  Zipcode_y                                  21608 non-null  category
# dtypes: category(1), float64(10), int64(9), object(2)
# memory usage: 3.6+ MB

# %%
q1=data["Sale Price"].quantile(0.25)
q3=data["Sale Price"].quantile(0.75)
(q1,q3)
# Out:
# (321837.5, 645000.0)

# %%
iqr=q3-q1
iqr
# Out:
# 323162.5

# %%
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

(upper_bound,lower_bound)
# Out:
# (1129743.75, -162906.25)

# %%
data["Sale Price"].max()
# Out:
# 7700000.0

# %%
plt.boxplot(data["Sale Price"])
plt.show()

# %%
data["Sale Price"].describe()
# Out:
# count    2.160800e+04
# mean     5.401938e+05
# std      3.673969e+05
# min      7.500000e+04
# 25%      3.218375e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %%
data["Sale Price"]
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: Sale Price, Length: 21608, dtype: float64

# %% [markdown]
# handlin outliers

# %%
def outliers(value):
    
    if value > upper_bound:
        return upper_bound
    elif value <lower_bound:
        return lower_bound
    else:
        return value
    
    
data["Sale Price"]=data["Sale Price"].map(outliers)

# %%
data["Sale Price"].max()
# Out:
# 1129743.75

# %%
pd.get_dummies(data,["Condition of the House"], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 pd.get_dummies(data,["Condition of the House"], drop_first=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\encoding.py:182, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     175             len_msg = (
#     176                 f"Length of '{name}' ({len(item)}) did not match the "
#     177                 "length of the columns being encoded "
#     178                 f"({data_to_encode.shape[1]})."
#     179             )
#     180             raise ValueError(len_msg)
# --> 182 check_len(prefix, "prefix")
#     183 check_len(prefix_sep, "prefix_sep")
#     185 if isinstance(prefix, str):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\encoding.py:180, in get_dummies.<locals>.check_len(item, name)
#     174 if not len(item) == data_to_encode.shape[1]:
#     175     len_msg = (
#     176         f"Length of '{name}' ({len(item)}) did not match the "
#     177         "length of the columns being encoded "
#     178         f"({data_to_encode.shape[1]})."
#     179     )
# --> 180     raise ValueError(len_msg)
#
# ValueError: Length of 'prefix' (1) did not match the length of the columns being encoded (3).

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21608 entries, 0 to 21612
# Data columns (total 22 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Zipcode                                    21608 non-null  float64
#  1   ID                                         21608 non-null  int64
#  2   Date House was Sold                        21608 non-null  int64
#  3   Sale Price                                 21608 non-null  float64
#  4   No of Bedrooms                             21608 non-null  int64
#  5   No of Bathrooms                            21608 non-null  float64
#  6   Flat Area (in Sqft)                        21608 non-null  float64
#  7   Lot Area (in Sqft)                         21608 non-null  float64
#  8   No of Floors                               21608 non-null  float64
#  9   Waterfront View                            21608 non-null  object
#  10  Condition of the House                     21608 non-null  object
#  11  Overall Grade                              21608 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21608 non-null  float64
#  13  Basement Area (in Sqft)                    21608 non-null  int64
#  14  Age of House (in Years)                    21608 non-null  int64
#  15  Renovated Year                             21608 non-null  int64
#  16  Latitude                                   21608 non-null  float64
#  17  Longitude                                  21608 non-null  float64
#  18  Living Area after Renovation (in Sqft)     21608 non-null  float64
#  19  Lot Area after Renovation (in Sqft)        21608 non-null  int64
#  20  Year since renovated                       21608 non-null  int64
#  21  Zipcode_y                                  21608 non-null  category
# dtypes: category(1), float64(10), int64(9), object(2)
# memory usage: 3.6+ MB

# %%
data
# Out:
#        Zipcode          ID  Date House was Sold  Sale Price  No of Bedrooms  \
# 0      98178.0  7129300520                 2017    221900.0               3
# 1      98125.0  6414100192                 2017    538000.0               3
# 2      98028.0  5631500400                 2016    180000.0               2
# 3      98136.0  2487200875                 2017    604000.0               4
# 4      98074.0  1954400510                 2016    510000.0               3
# ...        ...         ...                  ...         ...             ...
# 21608  98103.0   263000018                 2017    360000.0               3
# 21609  98146.0  6600060120                 2016    400000.0               4
# 21610  98144.0  1523300141                 2017    402101.0               2
# 21611  98027.0   291310100                 2016    400000.0               3
# 21612  98144.0  1523300157                 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# 1                 2.25               2570.0              7242.0           2.0
# 2                 1.00                770.0             10000.0           1.0
# 3                 3.00               1960.0              5000.0           1.0
# 4                 2.00               1680.0              8080.0           1.0
# ...                ...                  ...                 ...           ...
# 21608             2.50               1530.0              1131.0           3.0
# 21609             2.50               2310.0              5813.0           2.0
# 21610             0.75               1020.0              1350.0           2.0
# 21611             2.50               1600.0              2388.0           2.0
# 21612             0.75               1020.0              1076.0           2.0
#
#       Waterfront View  ... Area of the House from Basement (in Sqft)  \
# 0                  No  ...                                    1180.0
# 1                  No  ...                                    2170.0
# 2                  No  ...                                     770.0
# 3                  No  ...                                    1050.0
# 4                  No  ...                                    1680.0
# ...               ...  ...                                       ...
# 21608              No  ...                                    1530.0
# 21609              No  ...                                    2310.0
# 21610              No  ...                                    1020.0
# 21611              No  ...                                    1600.0
# 21612              No  ...                                    1020.0
#
#        Basement Area (in Sqft)  Age of House (in Years)  Renovated Year  \
# 0                            0                       63               0
# 1                          400                       67            1991
# 2                            0                       85               0
# 3                          910                       53               0
# 4                            0                       31               0
# ...                        ...                      ...             ...
# 21608                        0                        9               0
# 21609                        0                        4               0
# 21610                        0                        9               0
# 21611                        0                       14               0
# 21612                        0                       10               0
#
#        Latitude  Longitude  Living Area after Renovation (in Sqft)  \
# 0       47.5112   -122.257                                  1340.0
# 1       47.7210   -122.319                                  1690.0
# 2       47.7379   -122.233                                  2720.0
# 3       47.5208   -122.393                                  1360.0
# 4       47.6168   -122.045                                  1800.0
# ...         ...        ...                                     ...
# 21608   47.6993   -122.346                                  1530.0
# 21609   47.5107   -122.362                                  1830.0
# 21610   47.5944   -122.299                                  1020.0
# 21611   47.5345   -122.069                                  1410.0
# 21612   47.5941   -122.299                                  1020.0
#
#        Lot Area after Renovation (in Sqft)  Year since renovated  \
# 0                                     5650                     0
# 1                                     7639                    26
# 2                                     8062                     0
# 3                                     5000                     0
# 4                                     7503                     0
# ...                                    ...                   ...
# 21608                                 1509                     0
# 21609                                 7200                     0
# 21610                                 2007                     0
# 21611                                 1287                     0
# 21612                                 1357                     0
#
#              Zipcode_y
# 0      zipcode_group_0
# 1      zipcode_group_1
# 2      zipcode_group_1
# 3      zipcode_group_1
# 4      zipcode_group_2
# ...                ...
# 21608  zipcode_group_1
# 21609  zipcode_group_0
# 21610  zipcode_group_1
# 21611  zipcode_group_1
# 21612  zipcode_group_1
#
# [21608 rows x 22 columns]
